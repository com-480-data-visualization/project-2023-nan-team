# %%
import pandas as pd
df = pd.read_csv('data/swiss_all.csv')

# %%
x = df[df['Unnamed: 0']%4==0]
len(x)/len(df)
# Out:
# 0.25000728247254506

# %%
s = df[df['Z']>10]
s = s[s['Unnamed: 0']%2==0]
len(s)
# Out:
# 495507

# %%
import matplotlib.pyplot as plt
plt.scatter(df["X"], df["Y"], c=df["Unnamed: 0"])
plt.show()
